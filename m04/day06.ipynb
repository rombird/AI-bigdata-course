# %% [markdown]
# # TTS로 영어 듣기 평가 문제 만들기
# OpenAI api에는 문장을 음성파일로 변환하는 TTS(text-to-speeach)가 존재

# %%
# 라이브러리 불러오기 및 api key 설정
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key=os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
# 첫번째 TTS 테스트
response=client.audio.speech.create(
    model='tts-1-hd',
    voice='alloy',
    input='Hello world! This is a TTS test',
)
response.write_to_file('hello_world.mp3') # mp3로 파일 생성

# 재생
import IPython.display as ipd

ipd.Audio('hello_world.mp3') # 'alloy'의 목소리로 input 문장 음성파일로 변환
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 목소리를 바꾸고 TTS 테스트
# create speech로 들어가면 다양한 목소리 확인 가능
voice = 'ash'
mp3_file = f'hello_world_{voice}.mp3'

response=client.audio.speech.create(
    model='tts-1-hd',
    voice=voice,
    input=f"Hello world! I'm {voice}. This is a TTS test"
)

response.write_to_file(mp3_file)

# 재생
ipd.Audio(mp3_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 5일차에 받은 json파일 읽어보기 - 영어 스크립트 json 파일 읽기
import json
with open('./images/image_quiz_eng.json', 'r', encoding='utf-8') as f:
    eng_dict = json.load(f) # load -> 파이썬으로 읽기 쉽게 바뀜

eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Many people are gathered in one place.\n- (2) Various items are placed on the tables.\n- (3) There are many windows on the walls of the room.\n- (4) People seem to be participating in an event.',
#   'img': 'busan_dive.jpg'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) A yellow sculpture appears.\n- (2) The building has the words "Local Stitch" on it.\n- (3) The sculpture resembles a seated person.\n- (4) The building is made of bricks without any windows.',
#   'img': 'local_stitch.jpg'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are sitting inside the cafe.\n- (2) The central counter has a yellow section.\n- (3) Trees are visible outside the window.\n- (4) An employee is wearing black clothes.',
#   'img': 'local_stitch_terrarosa.jpg'},
#  {'no': 4,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) There is a red brick building in the image.\n- (2) The building has two floors.\n- (3) A sign that says "PERSONAL COFFEE" is visible.\n- (4) There is an orange cone in front of the building.',
#   'img': 'mangwon.jpg'},
#  {'no': 5,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Various types of bread are displayed.\n- (2) A staff member is arranging the bread.\n- (3) There are price tags on the bread.\n- (4) Sunlight is coming through the window.',
#   'img': 'mangwon_bakery.jpg'},
#  {'no': 6,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n\n- (1) People are working in front of a building.\n- (2) The sign on the building says "bakery cafe."\n- (3) Tools used by the workers are placed on the ground.\n- (4) The sign is orange in color.',
#   'img': 'sangam_interior.jpg'},
#  {'no': 7,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are sitting indoors and talking.\n- (2) There are multiple lights installed on the ceiling.\n- (3) Buildings are visible outside the windows.\n- (4) All tables are fully occupied by people.',
#   'img': 'seolleung_terrarosa.jpg'},
#  {'no': 8,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are lining up to get on the bus.\n- (2) There are buildings visible behind the crowd.\n- (3) A person in black clothing is talking on the phone.\n- (4) All the people are inside a café drinking coffee.',
#   'img': 'stanford_coffee.jpg'}]

# %%
# 여러 목소리를 추가한 영어스크립트 json 파일 읽기
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage', 'shimmer']
for q in eng_dict:
    no = q['no'] # q의 key=no를 no에 저장
    quiz = q['eng']
    quiz = quiz.replace('- (1)', '- One.\t') # (1)로 되어있으면 읽기 힘드니까 one으로 바꿔주기
    quiz = quiz.replace('- (2)', '- Two.\t')
    quiz = quiz.replace('- (3)', '- Three.\t')
    quiz = quiz.replace('- (4)', '- Four.\t')

    print(no, quiz)

    # 문제 번호에 따라 목소리 선택
    voice = voices[no % len(voices)] # 문제번호 8%9
    
    response=client.audio.speech.create(
        model='tts-1-hd',
        voice=voice,
        input=f'#{no}, {quiz}',
    )

    response.write_to_file(f'./audio/{no}.mp3')
# Out:
# 1 Which of the following descriptions of the image is incorrect?
# - One.	 Many people are gathered in one place.
# - Two.	 Various items are placed on the tables.
# - Three.	 There are many windows on the walls of the room.
# - Four.	 People seem to be participating in an event.
# 2 Which of the following descriptions of the image is incorrect?
# - One.	 A yellow sculpture appears.
# - Two.	 The building has the words "Local Stitch" on it.
# - Three.	 The sculpture resembles a seated person.
# - Four.	 The building is made of bricks without any windows.
# 3 Which of the following descriptions of the image is incorrect?
# - One.	 People are sitting inside the cafe.
# - Two.	 The central counter has a yellow section.
# - Three.	 Trees are visible outside the window.
# - Four.	 An employee is wearing black clothes.
# 4 Which of the following descriptions of the image is incorrect?
# - One.	 There is a red brick building in the image.
# - Two.	 The building has two floors.
# - Three.	 A sign that says "PERSONAL COFFEE" is visible.
# - Four.	 There is an orange cone in front of the building.
# 5 Which of the following descriptions of the image is incorrect?
# - One.	 Various types of bread are displayed.
# - Two.	 A staff member is arranging the bread.
# - Three.	 There are price tags on the bread.
# - Four.	 Sunlight is coming through the window.
# 6 Which of the following descriptions of the image is incorrect?
#
# - One.	 People are working in front of a building.
# - Two.	 The sign on the building says "bakery cafe."
# - Three.	 Tools used by the workers are placed on the ground.
# - Four.	 The sign is orange in color.
# 7 Which of the following descriptions of the image is incorrect?
# - One.	 People are sitting indoors and talking.
# - Two.	 There are multiple lights installed on the ceiling.
# - Three.	 Buildings are visible outside the windows.
# - Four.	 All tables are fully occupied by people.
# 8 Which of the following descriptions of the image is incorrect?
# - One.	 People are lining up to get on the bus.
# - Two.	 There are buildings visible behind the crowd.
# - Three.	 A person in black clothing is talking on the phone.
# - Four.	 All the people are inside a café drinking coffee.

# %%
# 재생
ipd.Audio('./audio/1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
